# %% [markdown]
# # L5 Data Engineer
# ## Module 6 Topic 1 - Webinar
# ## Introduction to Data Collection and Ingestion
#
# In this workshop we are going to learn how to perform data collection in Python

# %% [markdown]
# ## Loading the libraries
#
# In this case we are going to use the library pandas. You can find the documentation of the library [here](https://pandas.pydata.org/). This library is one of the most important libraries to analyse data in Python (It is connected with [Numpy](http://www.numpy.org/))

# %%
# Import the libraries
import pandas as pd
import numpy as np

# %%
# Reading the data from a website!
url_housepriceUK = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index-v2.xls"
houses = pd.read_excel(url_housepriceUK, sheet_name='Average price', index_col=0)

# %%
houses.head()
# Out:
#            City of London Barking & Dagenham     Barnet     Bexley      Brent  \
# NaT             E09000001          E09000002  E09000003  E09000004  E09000005
# 1995-01-01       91448.98           50460.23   93284.52   64958.09   71306.57
# 1995-02-01       82202.77           51085.78   93190.17   64787.92   72022.26
# 1995-03-01       79120.70           51268.97   92247.52   64367.49   72015.76
# 1995-04-01       77101.21           53133.51   90762.87   64277.67   72965.63
#
#               Bromley     Camden    Croydon     Ealing    Enfield  ...  \
# NaT         E09000006  E09000007  E09000008  E09000009  E09000010  ...
# 1995-01-01   81671.48  120932.89   69158.16   79885.89   72514.69  ...
# 1995-02-01   81657.56  119508.86   68951.10   80897.07   73155.20  ...
# 1995-03-01   81449.31  120282.21   68712.44   81379.86   72190.44  ...
# 1995-04-01   81124.41  120097.90   68610.05   82188.90   71442.92  ...
#
#            NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS  \
# NaT         E12000002          E12000003     E12000004     E12000005
# 1995-01-01   43958.48           44803.43      45544.52      48527.52
# 1995-02-01   43925.42           44528.81      46051.57      49341.29
# 1995-03-01   44434.87           45200.47      45383.82      49442.18
# 1995-04-01   44267.78           45614.34      46124.23      49455.93
#
#            EAST OF ENGLAND     LONDON SOUTH EAST SOUTH WEST Unnamed: 47  \
# NaT              E12000006  E12000007  E12000008  E12000009         NaN
# 1995-01-01        56701.60   74435.76   64018.88   54705.16         NaN
# 1995-02-01        56593.59   72777.94   63715.02   54356.15         NaN
# 1995-03-01        56171.18   73896.84   64113.61   53583.08         NaN
# 1995-04-01        56567.90   74455.29   64623.22   54786.02         NaN
#
#               England
# NaT         E92000001
# 1995-01-01   53202.77
# 1995-02-01   53096.15
# 1995-03-01   53201.28
# 1995-04-01   53590.85
#
# [5 rows x 48 columns]

# %%
# Let's have a look to the dimensions of the table
houses.shape
# Out:
# (355, 48)

# %%
# transpose the table
df = houses.T

# %%
df.head()
# Out:
#                           NaT 1995-01-01 1995-02-01 1995-03-01 1995-04-01  \
# City of London      E09000001   91448.98   82202.77   79120.70   77101.21
# Barking & Dagenham  E09000002   50460.23   51085.78   51268.97   53133.51
# Barnet              E09000003   93284.52   93190.17   92247.52   90762.87
# Bexley              E09000004   64958.09   64787.92   64367.49   64277.67
# Brent               E09000005   71306.57   72022.26   72015.76   72965.63
#
#                    1995-05-01 1995-06-01 1995-07-01 1995-08-01 1995-09-01  \
# City of London       84409.15   94900.51  110128.04  112329.44  104473.11
# Barking & Dagenham   53042.25   53700.35   52113.12   52232.20   51471.61
# Barnet               90258.00   90107.23   91441.25   92361.32   93273.12
# Bexley               63997.14   64252.32   63722.70   64432.60   64509.55
# Brent                73704.05   74310.48   74127.04   73547.04   73789.54
#
#                     ... 2023-09-01 2023-10-01 2023-11-01 2023-12-01  \
# City of London      ...     936965     878204     853893     813400
# Barking & Dagenham  ...     336784     337251     340263     338341
# Barnet              ...     589889     580546     581085     582023
# Bexley              ...     398403     393381     396275     391739
# Brent               ...     538074     532596     518885     507287
#
#                    2024-01-01 2024-02-01 2024-03-01 2024-04-01 2024-05-01  \
# City of London         828979     849938     826707     810829     829091
# Barking & Dagenham     332732     329987     335377     337073     336654
# Barnet                 580848     571767     571276     569628     575571
# Bexley                 394804     396589     398238     402705     405443
# Brent                  520617     526461     511210     498630     494217
#
#                    2024-06-01
# City of London         828527
# Barking & Dagenham     340403
# Barnet                 585639
# Bexley                 415496
# Brent                  539180
#
# [5 rows x 355 columns]

# %%
#What does the following function do?
df=df.reset_index()

# %%
df.head()
# Out:
#                 index        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001            91448.98            82202.77
# 1  Barking & Dagenham  E09000002            50460.23            51085.78
# 2              Barnet  E09000003            93284.52            93190.17
# 3              Bexley  E09000004            64958.09            64787.92
# 4               Brent  E09000005            71306.57            72022.26
#
#   1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0            79120.70            77101.21            84409.15
# 1            51268.97            53133.51            53042.25
# 2            92247.52            90762.87            90258.00
# 3            64367.49            64277.67            63997.14
# 4            72015.76            72965.63            73704.05
#
#   1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0            94900.51           110128.04           112329.44  ...
# 1            53700.35            52113.12            52232.20  ...
# 2            90107.23            91441.25            92361.32  ...
# 3            64252.32            63722.70            64432.60  ...
# 4            74310.48            74127.04            73547.04  ...
#
#   2023-09-01 00:00:00 2023-10-01 00:00:00 2023-11-01 00:00:00  \
# 0              936965              878204              853893
# 1              336784              337251              340263
# 2              589889              580546              581085
# 3              398403              393381              396275
# 4              538074              532596              518885
#
#   2023-12-01 00:00:00 2024-01-01 00:00:00 2024-02-01 00:00:00  \
# 0              813400              828979              849938
# 1              338341              332732              329987
# 2              582023              580848              571767
# 3              391739              394804              396589
# 4              507287              520617              526461
#
#   2024-03-01 00:00:00 2024-04-01 00:00:00 2024-05-01 00:00:00  \
# 0              826707              810829              829091
# 1              335377              337073              336654
# 2              571276              569628              575571
# 3              398238              402705              405443
# 4              511210              498630              494217
#
#   2024-06-01 00:00:00
# 0              828527
# 1              340403
# 2              585639
# 3              415496
# 4              539180
#
# [5 rows x 356 columns]

# %%
# Let's check the column names
df.columns
# Out:
# Index([            'index',                 NaT, 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-09-01 00:00:00, 2023-10-01 00:00:00, 2023-11-01 00:00:00,
#        2023-12-01 00:00:00, 2024-01-01 00:00:00, 2024-02-01 00:00:00,
#        2024-03-01 00:00:00, 2024-04-01 00:00:00, 2024-05-01 00:00:00,
#        2024-06-01 00:00:00],
#       dtype='object', length=356)

# %%
# Change the name of a column
df = df.rename(columns = {'index':'Borough', pd.NaT: 'ID'})

# %%
df.columns
# Out:
# Index([          'Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-09-01 00:00:00, 2023-10-01 00:00:00, 2023-11-01 00:00:00,
#        2023-12-01 00:00:00, 2024-01-01 00:00:00, 2024-02-01 00:00:00,
#        2024-03-01 00:00:00, 2024-04-01 00:00:00, 2024-05-01 00:00:00,
#        2024-06-01 00:00:00],
#       dtype='object', length=356)

# %%
data_frame = pd.melt(df, id_vars= ['Borough', 'ID'])

# %%
data_frame.head()
# Out:
#               Borough         ID             variable    value
# 0      City of London  E09000001  1995-01-01 00:00:00 91448.98
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00 50460.23
# 2              Barnet  E09000003  1995-01-01 00:00:00 93284.52
# 3              Bexley  E09000004  1995-01-01 00:00:00 64958.09
# 4               Brent  E09000005  1995-01-01 00:00:00 71306.57

# %%
data_frame = data_frame.rename(columns = {'variable':'Time', 'value': 'Average_price'})

# %%
data_frame.head()
# Out:
#               Borough         ID                 Time Average_price
# 0      City of London  E09000001  1995-01-01 00:00:00      91448.98
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00      50460.23
# 2              Barnet  E09000003  1995-01-01 00:00:00      93284.52
# 3              Bexley  E09000004  1995-01-01 00:00:00      64958.09
# 4               Brent  E09000005  1995-01-01 00:00:00      71306.57

# %%
data_frame.dtypes
# Out:
# Borough          object
# ID               object
# Time             object
# Average_price    object
# dtype: object

# %% [markdown]
# How to select particular column in a dataframe :D

# %%
data_frame['Average_price'] = pd.to_numeric(data_frame['Average_price'])

# %%
data_frame.dtypes
# Out:
# Borough           object
# ID                object
# Time              object
# Average_price    float64
# dtype: object

# %%
data_frame.count()
# Out:
# Borough          16992
# ID               15930
# Time             16992
# Average_price    15930
# dtype: int64

# %%
data_frame.Borough.unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
data_frame[data_frame.Borough == 'Unnamed: 33'].head()
# Out:
# Empty DataFrame
# Columns: [Borough, ID, Time, Average_price]
# Index: []

# %%
data_frame[data_frame.Borough == 'Unnamed: 36'].head()
# Out:
# Empty DataFrame
# Columns: [Borough, ID, Time, Average_price]
# Index: []

# %%
# Lets check a dataframe only with NaN values in the ID
data_frame[data_frame.ID.isna()]
# Out:
#            Borough   ID                 Time  Average_price
# 33     Unnamed: 34  NaN  1995-01-01 00:00:00            NaN
# 36     Unnamed: 37  NaN  1995-01-01 00:00:00            NaN
# 46     Unnamed: 47  NaN  1995-01-01 00:00:00            NaN
# 81     Unnamed: 34  NaN  1995-02-01 00:00:00            NaN
# 84     Unnamed: 37  NaN  1995-02-01 00:00:00            NaN
# ...            ...  ...                  ...            ...
# 16932  Unnamed: 37  NaN  2024-05-01 00:00:00            NaN
# 16942  Unnamed: 47  NaN  2024-05-01 00:00:00            NaN
# 16977  Unnamed: 34  NaN  2024-06-01 00:00:00            NaN
# 16980  Unnamed: 37  NaN  2024-06-01 00:00:00            NaN
# 16990  Unnamed: 47  NaN  2024-06-01 00:00:00            NaN
#
# [1062 rows x 4 columns]

# %%
# How are we going to deal with NaN values?
# in this case it seems that there were original empty entries
# Challenge 1 find two different ways to drop NaN values

## First method
# filtering

df_clean1 = data_frame[data_frame.Average_price.notna()]
df_clean1.head(48)
# Out:
#                  Borough         ID                 Time  Average_price
# 0         City of London  E09000001  1995-01-01 00:00:00       91448.98
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00       50460.23
# 2                 Barnet  E09000003  1995-01-01 00:00:00       93284.52
# 3                 Bexley  E09000004  1995-01-01 00:00:00       64958.09
# 4                  Brent  E09000005  1995-01-01 00:00:00       71306.57
# 5                Bromley  E09000006  1995-01-01 00:00:00       81671.48
# 6                 Camden  E09000007  1995-01-01 00:00:00      120932.89
# 7                Croydon  E09000008  1995-01-01 00:00:00       69158.16
# 8                 Ealing  E09000009  1995-01-01 00:00:00       79885.89
# 9                Enfield  E09000010  1995-01-01 00:00:00       72514.69
# 10             Greenwich  E09000011  1995-01-01 00:00:00       62300.10
# 11               Hackney  E09000012  1995-01-01 00:00:00       61296.53
# 12  Hammersmith & Fulham  E09000013  1995-01-01 00:00:00      124902.86
# 13              Haringey  E09000014  1995-01-01 00:00:00       76287.57
# 14                Harrow  E09000015  1995-01-01 00:00:00       84769.53
# 15              Havering  E09000016  1995-01-01 00:00:00       68000.14
# 16            Hillingdon  E09000017  1995-01-01 00:00:00       73834.83
# 17              Hounslow  E09000018  1995-01-01 00:00:00       72231.71
# 18             Islington  E09000019  1995-01-01 00:00:00       92516.49
# 19  Kensington & Chelsea  E09000020  1995-01-01 00:00:00      182694.83
# 20  Kingston upon Thames  E09000021  1995-01-01 00:00:00       80875.85
# 21               Lambeth  E09000022  1995-01-01 00:00:00       67770.99
# 22              Lewisham  E09000023  1995-01-01 00:00:00       60491.26
# 23                Merton  E09000024  1995-01-01 00:00:00       82070.61
# 24                Newham  E09000025  1995-01-01 00:00:00       53539.32
# 25             Redbridge  E09000026  1995-01-01 00:00:00       72189.58
# 26  Richmond upon Thames  E09000027  1995-01-01 00:00:00      109326.12
# 27             Southwark  E09000028  1995-01-01 00:00:00       67885.20
# 28                Sutton  E09000029  1995-01-01 00:00:00       71536.97
# 29         Tower Hamlets  E09000030  1995-01-01 00:00:00       59865.19
# 30        Waltham Forest  E09000031  1995-01-01 00:00:00       61319.45
# 31            Wandsworth  E09000032  1995-01-01 00:00:00       88559.04
# 32           Westminster  E09000033  1995-01-01 00:00:00      133025.28
# 34          Inner London  E13000001  1995-01-01 00:00:00       78251.98
# 35          Outer London  E13000002  1995-01-01 00:00:00       72958.80
# 37            NORTH EAST  E12000001  1995-01-01 00:00:00       42076.35
# 38            NORTH WEST  E12000002  1995-01-01 00:00:00       43958.48
# 39    YORKS & THE HUMBER  E12000003  1995-01-01 00:00:00       44803.43
# 40         EAST MIDLANDS  E12000004  1995-01-01 00:00:00       45544.52
# 41         WEST MIDLANDS  E12000005  1995-01-01 00:00:00       48527.52
# 42       EAST OF ENGLAND  E12000006  1995-01-01 00:00:00       56701.60
# 43                LONDON  E12000007  1995-01-01 00:00:00       74435.76
# 44            SOUTH EAST  E12000008  1995-01-01 00:00:00       64018.88
# 45            SOUTH WEST  E12000009  1995-01-01 00:00:00       54705.16
# 47               England  E92000001  1995-01-01 00:00:00       53202.77
# 48        City of London  E09000001  1995-02-01 00:00:00       82202.77
# 49    Barking & Dagenham  E09000002  1995-02-01 00:00:00       51085.78
# 50                Barnet  E09000003  1995-02-01 00:00:00       93190.17

# %%
df_clean1.count()
# Out:
# Borough          15930
# ID               15930
# Time             15930
# Average_price    15930
# dtype: int64

# %%
# filtering the data with NaN values
df_clean2 = data_frame.dropna()
df_clean2.head(48)
# Out:
#                  Borough         ID                 Time  Average_price
# 0         City of London  E09000001  1995-01-01 00:00:00       91448.98
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00       50460.23
# 2                 Barnet  E09000003  1995-01-01 00:00:00       93284.52
# 3                 Bexley  E09000004  1995-01-01 00:00:00       64958.09
# 4                  Brent  E09000005  1995-01-01 00:00:00       71306.57
# 5                Bromley  E09000006  1995-01-01 00:00:00       81671.48
# 6                 Camden  E09000007  1995-01-01 00:00:00      120932.89
# 7                Croydon  E09000008  1995-01-01 00:00:00       69158.16
# 8                 Ealing  E09000009  1995-01-01 00:00:00       79885.89
# 9                Enfield  E09000010  1995-01-01 00:00:00       72514.69
# 10             Greenwich  E09000011  1995-01-01 00:00:00       62300.10
# 11               Hackney  E09000012  1995-01-01 00:00:00       61296.53
# 12  Hammersmith & Fulham  E09000013  1995-01-01 00:00:00      124902.86
# 13              Haringey  E09000014  1995-01-01 00:00:00       76287.57
# 14                Harrow  E09000015  1995-01-01 00:00:00       84769.53
# 15              Havering  E09000016  1995-01-01 00:00:00       68000.14
# 16            Hillingdon  E09000017  1995-01-01 00:00:00       73834.83
# 17              Hounslow  E09000018  1995-01-01 00:00:00       72231.71
# 18             Islington  E09000019  1995-01-01 00:00:00       92516.49
# 19  Kensington & Chelsea  E09000020  1995-01-01 00:00:00      182694.83
# 20  Kingston upon Thames  E09000021  1995-01-01 00:00:00       80875.85
# 21               Lambeth  E09000022  1995-01-01 00:00:00       67770.99
# 22              Lewisham  E09000023  1995-01-01 00:00:00       60491.26
# 23                Merton  E09000024  1995-01-01 00:00:00       82070.61
# 24                Newham  E09000025  1995-01-01 00:00:00       53539.32
# 25             Redbridge  E09000026  1995-01-01 00:00:00       72189.58
# 26  Richmond upon Thames  E09000027  1995-01-01 00:00:00      109326.12
# 27             Southwark  E09000028  1995-01-01 00:00:00       67885.20
# 28                Sutton  E09000029  1995-01-01 00:00:00       71536.97
# 29         Tower Hamlets  E09000030  1995-01-01 00:00:00       59865.19
# 30        Waltham Forest  E09000031  1995-01-01 00:00:00       61319.45
# 31            Wandsworth  E09000032  1995-01-01 00:00:00       88559.04
# 32           Westminster  E09000033  1995-01-01 00:00:00      133025.28
# 34          Inner London  E13000001  1995-01-01 00:00:00       78251.98
# 35          Outer London  E13000002  1995-01-01 00:00:00       72958.80
# 37            NORTH EAST  E12000001  1995-01-01 00:00:00       42076.35
# 38            NORTH WEST  E12000002  1995-01-01 00:00:00       43958.48
# 39    YORKS & THE HUMBER  E12000003  1995-01-01 00:00:00       44803.43
# 40         EAST MIDLANDS  E12000004  1995-01-01 00:00:00       45544.52
# 41         WEST MIDLANDS  E12000005  1995-01-01 00:00:00       48527.52
# 42       EAST OF ENGLAND  E12000006  1995-01-01 00:00:00       56701.60
# 43                LONDON  E12000007  1995-01-01 00:00:00       74435.76
# 44            SOUTH EAST  E12000008  1995-01-01 00:00:00       64018.88
# 45            SOUTH WEST  E12000009  1995-01-01 00:00:00       54705.16
# 47               England  E92000001  1995-01-01 00:00:00       53202.77
# 48        City of London  E09000001  1995-02-01 00:00:00       82202.77
# 49    Barking & Dagenham  E09000002  1995-02-01 00:00:00       51085.78
# 50                Barnet  E09000003  1995-02-01 00:00:00       93190.17

# %%
df_clean2.count()
# Out:
# Borough          15930
# ID               15930
# Time             15930
# Average_price    15930
# dtype: int64

# %% [markdown]
# Let's use the df_clean2 dataset for the next analysis because it contains all the boroughs in London

# %%
#So far we have seen different data types such an objects, numerical values and dates.
# Now we are going to create new variables based on the date to have only year variable.
df_ready = df_clean2

# %%
df_ready.loc[:,'Year'] = df_ready.Time.apply(lambda x: x.year)
# Out:
# <ipython-input-188-9f600d545688>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ready.loc[:,'Year'] = df_ready.Time.apply(lambda x: x.year)

# %%
df_ready.head()
# Out:
#               Borough         ID                 Time  Average_price  Year
# 0      City of London  E09000001  1995-01-01 00:00:00       91448.98  1995
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00       50460.23  1995
# 2              Barnet  E09000003  1995-01-01 00:00:00       93284.52  1995
# 3              Bexley  E09000004  1995-01-01 00:00:00       64958.09  1995
# 4               Brent  E09000005  1995-01-01 00:00:00       71306.57  1995

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_ready.Average_price.describe()
# Out:
# count     15930.00
# mean     298750.52
# std      210626.06
# min       40722.42
# 25%      147313.14
# 50%      245464.14
# 75%      405873.45
# max     1527966.00
# Name: Average_price, dtype: float64

# %%
df_ready = df_ready.drop(columns=['ID', 'Time'])
df_ready.head()
# Out:
#               Borough  Average_price  Year
# 0      City of London       91448.98  1995
# 1  Barking & Dagenham       50460.23  1995
# 2              Barnet       93284.52  1995
# 3              Bexley       64958.09  1995
# 4               Brent       71306.57  1995

# %%
df_year = df_ready.groupby(by=['Borough','Year']).mean()
df_year.sample(15)
# Out:
#                          Average_price
# Borough            Year
# Newham             1998       67671.27
# City of London     1996      105651.06
# Ealing             2004      241038.54
# City of London     2013      570008.71
# Enfield            2017      395929.18
# Hillingdon         2011      251781.66
# Merton             2011      306063.02
# Southwark          2023      491953.92
# WEST MIDLANDS      1998       56912.85
# Tower Hamlets      2007      287172.87
# NORTH WEST         2005      126355.03
# Bexley             2007      208085.87
# Enfield            2001      135713.17
# Camden             2011      554392.96
# Barking & Dagenham 2024      335371.00

# %%
df_final = df_year.reset_index()
df_final.head(3)
# Out:
#               Borough  Year  Average_price
# 0  Barking & Dagenham  1995       51817.97
# 1  Barking & Dagenham  1996       51718.19
# 2  Barking & Dagenham  1997       55974.26

# %%
#function takes d (which is a dictionary of prices for grouped/sorted boroughs)
#and creates a dictionary of the price ratio from today to 20/15/10/5 years ago
def createPriceRatio(d):
     return [float(d.Average_price[d.Year == 2018].iloc[0])/float(d.Average_price[d.Year == 1998].iloc[0]),
                                           float(d.Average_price[d.Year == 2018].iloc[0])/float(d.Average_price[d.Year == 2003].iloc[0]),
                                           float(d.Average_price[d.Year == 2018].iloc[0])/float(d.Average_price[d.Year == 2008].iloc[0]),
                                           float(d.Average_price[d.Year == 2018].iloc[0])/float(d.Average_price[d.Year == 2013].iloc[0])]

# %%
print("first unique borough", df_final.Borough.unique()[0])
createPriceRatio(df_final[df_final.Borough == df_final.Borough.unique()[0]])
# Out:
# first unique borough Barking & Dagenham
# [4.89661861291754, 2.0715711912301606, 1.5755850332863885, 1.6991337959185635]

# %%
final = {}
for i in range(len(df_final.Borough.unique())):
    d = df_final[df_final.Borough == df_final.Borough.unique()[i]]
    final[df_final.Borough.unique()[i]] = createPriceRatio(d)
print(final['Barking & Dagenham'])
# Out:
# [4.89661861291754, 2.0715711912301606, 1.5755850332863885, 1.6991337959185635]

# %%
final= pd.DataFrame(final)
final=final.T
final = final.reset_index()
final.head()
# Out:
#                 index    0    1    2    3
# 0  Barking & Dagenham 4.90 2.07 1.58 1.70
# 1              Barnet 4.36 2.12 1.62 1.42
# 2              Bexley 4.25 2.08 1.63 1.60
# 3               Brent 4.89 2.28 1.68 1.45
# 4             Bromley 4.09 2.05 1.60 1.49

# %%
final = final.rename(columns = {'index':'Borough',0:'20y', 1:'15y', 2:'10y', 3:'5y'})

final.head()
# Out:
#               Borough  20y  15y  10y   5y
# 0  Barking & Dagenham 4.90 2.07 1.58 1.70
# 1              Barnet 4.36 2.12 1.62 1.42
# 2              Bexley 4.25 2.08 1.63 1.60
# 3               Brent 4.89 2.28 1.68 1.45
# 4             Bromley 4.09 2.05 1.60 1.49

# %%
sns.barplot(y='20y', x='Borough', data=final)
# Out:
# <Axes: xlabel='Borough', ylabel='20y'>

# %%
Top10_20y = final.sort_values(by='20y', ascending= False).head(10)
Top10_20y
# Out:
#                  Borough  20y  15y  10y   5y
# 14               Hackney 6.20 2.71 1.75 1.46
# 41        Waltham Forest 5.83 2.52 1.89 1.73
# 37             Southwark 5.52 2.53 1.73 1.40
# 27              Lewisham 5.45 2.41 1.78 1.58
# 43           Westminster 5.35 2.81 1.89 1.29
# 31                Newham 5.31 2.13 1.62 1.61
# 6         City of London 5.30 2.90 1.84 1.38
# 21          Inner London 5.17 2.50 1.72 1.39
# 16              Haringey 5.13 2.50 1.82 1.48
# 23  Kensington & Chelsea 5.08 2.96 1.74 1.21

# %%
Top10_15y = final.sort_values(by='15y', ascending= False).head(10)
Top10_15y
# Out:
#                  Borough  20y  15y  10y   5y
# 23  Kensington & Chelsea 5.08 2.96 1.74 1.21
# 6         City of London 5.30 2.90 1.84 1.38
# 43           Westminster 5.35 2.81 1.89 1.29
# 14               Hackney 6.20 2.71 1.75 1.46
# 5                 Camden 4.94 2.61 1.68 1.26
# 37             Southwark 5.52 2.53 1.73 1.40
# 41        Waltham Forest 5.83 2.52 1.89 1.73
# 26               Lambeth 4.96 2.52 1.73 1.41
# 16              Haringey 5.13 2.50 1.82 1.48
# 21          Inner London 5.17 2.50 1.72 1.39

# %%
Top10_5y = final.sort_values(by='5y', ascending= False).head(10)
Top10_5y
# Out:
#                Borough  20y  15y  10y   5y
# 41      Waltham Forest 5.83 2.52 1.89 1.73
# 0   Barking & Dagenham 4.90 2.07 1.58 1.70
# 18            Havering 4.33 2.07 1.60 1.64
# 31              Newham 5.31 2.13 1.62 1.61
# 2               Bexley 4.25 2.08 1.63 1.60
# 7              Croydon 4.20 1.99 1.57 1.58
# 27            Lewisham 5.45 2.41 1.78 1.58
# 33           Redbridge 4.47 2.08 1.60 1.54
# 13           Greenwich 4.76 2.27 1.68 1.53
# 19          Hillingdon 4.20 2.02 1.61 1.52

# %%
df_ready.Average_price.max()
# Out:
# 1527966.0
